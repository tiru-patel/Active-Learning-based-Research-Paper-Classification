# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = 'arxiv-metadata-oai-snapshot.json'

# %%
import ijson

# %%
with open(filename) as f:
    lines = f.read().splitlines()

# %%
df_inter = pd.DataFrame(lines)
df_inter.columns = ['json_element']

# %%
df_inter.head(5)
# Out:
#                                         json_element
# 0  {"id":"0704.0001","submitter":"Pavel Nadolsky"...
# 1  {"id":"0704.0002","submitter":"Louis Theran","...
# 2  {"id":"0704.0003","submitter":"Hongjun Pan","a...
# 3  {"id":"0704.0004","submitter":"David Callan","...
# 4  {"id":"0704.0005","submitter":"Alberto Torchin...

# %%
import json

df_inter['json_element'].apply(json.loads)
# Out:
# 0          {'id': '0704.0001', 'submitter': 'Pavel Nadols...
# 1          {'id': '0704.0002', 'submitter': 'Louis Theran...
# 2          {'id': '0704.0003', 'submitter': 'Hongjun Pan'...
# 3          {'id': '0704.0004', 'submitter': 'David Callan...
# 4          {'id': '0704.0005', 'submitter': 'Alberto Torc...
#                                  ...
# 2155067    {'id': 'supr-con/9608008', 'submitter': 'Rusla...
# 2155068    {'id': 'supr-con/9609001', 'submitter': 'Durga...
# 2155069    {'id': 'supr-con/9609002', 'submitter': 'Durga...
# 2155070    {'id': 'supr-con/9609003', 'submitter': 'Haseg...
# 2155071    {'id': 'supr-con/9609004', 'submitter': 'Masan...
# Name: json_element, Length: 2155072, dtype: object

# %%
df_final = pd.json_normalize(df_inter['json_element'].apply(json.loads))

# %%
df_final.head(30)
# Out:
#            id                submitter  \
# 0   0704.0001           Pavel Nadolsky
# 1   0704.0002             Louis Theran
# 2   0704.0003              Hongjun Pan
# 3   0704.0004             David Callan
# 4   0704.0005       Alberto Torchinsky
# 5   0704.0006             Yue Hin Pong
# 6   0704.0007        Alejandro Corichi
# 7   0704.0008             Damian Swift
# 8   0704.0009              Paul Harvey
# 9   0704.0010       Sergei Ovchinnikov
# 10  0704.0011       Clifton Cunningham
# 11  0704.0012              Dohoon Choi
# 12  0704.0013              Dohoon Choi
# 13  0704.0014             Koichi Fujii
# 14  0704.0015          Christian Stahn
# 15  0704.0016                  Li Tong
# 16  0704.0017            Nceba Mhlahlo
# 17  0704.0018       Andreas Gustavsson
# 18  0704.0019              Norio Konno
# 19  0704.0020          Patrick Roudeau
# 20  0704.0021           Yuichi Togashi
# 21  0704.0022             Simon Malham
# 22  0704.0023        Maria Loukitcheva
# ...

# %%
df_final.shape
# Out:
# (2155072, 14)

# %%
searchfor = ['cs.AI', 'cs.OS', 'cs.HC', 'cs.DB', 'cs.IR', 'cs.CG', 'cs.FL']

df_filtered = df_final.loc[df_final['categories'].isin(searchfor)]

# %%
df_filtered.shape
# Out:
# (20998, 14)

# %%
df_filter_cs['categories'] = df_filter_cs['categories'].str.split(' ')
# Out:
# /var/folders/3p/m4ddxh8d6ddgsr3nzqj7z7w00000gn/T/ipykernel_14951/996816419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter_cs['categories'] = df_filter_cs['categories'].str.split(' ')

# %%
df_filter_cs.head(5)
# Out:
#             id          submitter                          authors  \
# 1    0704.0002       Louis Theran  Ileana Streinu and Louis Theran
# 46   0704.0047        Igor Grabec           T. Kosel and I. Grabec
# 49   0704.0050        Igor Grabec           T. Kosel and I. Grabec
# 303  0704.0304  Carlos Gershenson                Carlos Gershenson
# 984  0704.0985       Mohd Abubakr          Mohd Abubakr, R.M.Vinay
#
#                                                  title  \
# 1             Sparsity-certifying Graph Decompositions
# 46   Intelligent location of simultaneously active ...
# 49   Intelligent location of simultaneously active ...
# 303                  The World as Evolving Information
# 984  Architecture for Pseudo Acausal Evolvable Embe...
#
#                                               comments  \
# 1                To appear in Graphs and Combinatorics
# 46           5 pages, 5 eps figures, uses IEEEtran.cls
# 49           5 pages, 7 eps figures, uses IEEEtran.cls
# ...

# %%
df_filtered.head(5)
# Out:
#              id           submitter  \
# 1393  0704.1394  Tarik Had\v{z}i\'c
# 2009  0704.2010   Juliana Bernardes
# 2541  0704.2542        Joan Llobera
# 3432  0704.3433   Tshilidzi Marwala
# 3499  0704.3500      Jerome Darmont
#
#                                                 authors  \
# 1393  Tarik Hadzic, Rune Moller Jensen, Henrik Reif ...
# 2009  Juliana S Bernardes, Alberto Davila, Vitor San...
# 2541                                       Joan Llobera
# 3432            Tshilidzi Marwala and Bodie Crossingham
# 3499                 Zhen He, J\'er\^ome Darmont (ERIC)
#
#                                                   title             comments  \
# 1393  Calculating Valid Domains for BDD-Based Intera...                 None
# 2009  A study of structural properties on profiles HMMs   6 pages, 7 figures
# 2541           Narratives within immersive technologies              5 pages
# 3432                     Bayesian approach to rough set  20 pages, 3 figures
# ...

# %%
df_filtered['cat_len'] = df_filtered['categories'].str.len()
# Out:
# /var/folders/3p/m4ddxh8d6ddgsr3nzqj7z7w00000gn/T/ipykernel_14951/2531454349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['cat_len'] = df_filtered['categories'].str.len()

# %%
df_filtered.head(5)
# Out:
#              id           submitter  \
# 1393  0704.1394  Tarik Had\v{z}i\'c
# 2009  0704.2010   Juliana Bernardes
# 2541  0704.2542        Joan Llobera
# 3432  0704.3433   Tshilidzi Marwala
# 3499  0704.3500      Jerome Darmont
#
#                                                 authors  \
# 1393  Tarik Hadzic, Rune Moller Jensen, Henrik Reif ...
# 2009  Juliana S Bernardes, Alberto Davila, Vitor San...
# 2541                                       Joan Llobera
# 3432            Tshilidzi Marwala and Bodie Crossingham
# 3499                 Zhen He, J\'er\^ome Darmont (ERIC)
#
#                                                   title             comments  \
# 1393  Calculating Valid Domains for BDD-Based Intera...                 None
# 2009  A study of structural properties on profiles HMMs   6 pages, 7 figures
# 2541           Narratives within immersive technologies              5 pages
# 3432                     Bayesian approach to rough set  20 pages, 3 figures
# ...

# %%
df_fin = df_filtered[df_filtered['cat_len'] == 5]

# %%
df_fin.shape
# Out:
# (20998, 16)

# %%
df_fin.to_csv('final_df.csv')

# %%
df_filtered['categories'].unique()
# Out:
# array(['cs.AI', 'cs.HC', 'cs.DB', 'cs.CG', 'cs.IR', 'cs.OS', 'cs.FL'],
#       dtype=object)

# %%
df_final

# %%
df_filtered.shape
# Out:
# (20998, 14)

# %%
df_filtered.head(5)
# Out:
#              id           submitter  \
# 1393  0704.1394  Tarik Had\v{z}i\'c
# 2009  0704.2010   Juliana Bernardes
# 2541  0704.2542        Joan Llobera
# 3432  0704.3433   Tshilidzi Marwala
# 3499  0704.3500      Jerome Darmont
#
#                                                 authors  \
# 1393  Tarik Hadzic, Rune Moller Jensen, Henrik Reif ...
# 2009  Juliana S Bernardes, Alberto Davila, Vitor San...
# 2541                                       Joan Llobera
# 3432            Tshilidzi Marwala and Bodie Crossingham
# 3499                 Zhen He, J\'er\^ome Darmont (ERIC)
#
#                                                   title             comments  \
# 1393  Calculating Valid Domains for BDD-Based Intera...                 None
# 2009  A study of structural properties on profiles HMMs   6 pages, 7 figures
# 2541           Narratives within immersive technologies              5 pages
# 3432                     Bayesian approach to rough set  20 pages, 3 figures
# ...

# %%
df_filtered.to_csv('final_df.csv')

# %%
df_filtered = df_filtered.reset_index()

# %%
df_filtered.to_csv('final_df.csv')

# %%
df_filtered.drop(columns=['index'], axis=1, inplace=True)

# %%
df_filtered.shape
# Out:
# (20998, 14)
